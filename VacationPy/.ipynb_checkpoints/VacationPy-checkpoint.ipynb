# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os


# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_data = pd.read_csv ('City.csv')
city_data
# Out:
#           City Name  Latitude  Longitude  Temperature  Wind Speed  Cloudiness  \
# 0         sinnamary    5.3833   -52.9500        80.92        9.48          99
# 1            dingle   10.9995   122.6711        78.01        6.93          48
# 2           rikitea  -23.1203  -134.9692        77.16       15.70          76
# 3             mezen   65.8522    44.2400        33.21        5.01         100
# 4            marawi    7.9986   124.2928        69.93        2.98         100
# ..              ...       ...        ...          ...         ...         ...
# 559            adre   13.4667    22.2000        85.53        8.63         100
# 560          sabang    5.8933    95.3214        82.27       18.28         100
# 561         hlobyne   49.3878    33.2596        60.10       11.97         100
# 562  nisia floresta   -6.0911   -35.2086        84.58        9.60          35
# 563     el transito   13.3500   -88.3500        92.86        6.46          63
#
#      Humidity Country        Date
# 0          80      GF  1650918158
# 1          88      PH  1650918158
# 2          72      PF  1650917936
# 3          90      RU  1650918159
# 4          91      PH  1650918159
# ..        ...     ...         ...
# 559        29      TD  1650918381
# 560        78      ID  1650918346
# 561        68      UA  1650918382
# 562        81      BR  1650918383
# 563        51      SV  1650918383
#
# [564 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_weather = city_data.loc[(city_data['Temperature'] >= 70) & (city_data['Temperature'] <= 80)]

ideal_weather 

clean_data=ideal_weather .dropna(axis=0)

clean_data
# Out:
#                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
# [122 rows x 9 columns]

# %%
hotel_df = clean_data
hotel_df
# Out:
#                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
# [122 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df['Hotel Name'] = ""

hotel_df
# Out:
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_49345/1528434106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ""
#                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date Hotel Name
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...        ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
# [122 rows x 10 columns]

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
    
    lat = row['Latitude']
    lon = row['Longitude']
    
    params['location']= f'{lat},{lon}'


    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {row['City Name']}.")
    
    response = requests.get(base_url, params=params).json()
    
    # extract results
    results = response['results']
    
    try:
        print(f"Closest {hotel_df} hotel is {results[0]['name']}.")
        
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
    
 
    params
# Out:
# Retrieving Results for Index 1: dingle.
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date Hotel Name
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...        ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
# [122 rows x 10 columns] hotel is SEGAYA PROPERTY.
# ------------
# Retrieving Results for Index 2: rikitea.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date       Hotel Name
# 1            48        88      PH  1650918158  SEGAYA PROPERTY
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...              ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
# [122 rows x 10 columns] hotel is People ThankYou.
# ------------
# Retrieving Results for Index 10: sechura.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date       Hotel Name
# 1            48        88      PH  1650918158  SEGAYA PROPERTY
# 2            76        72      PF  1650917936  People ThankYou
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...              ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
# [122 rows x 10 columns] hotel is Hospedaje Costa Bella.
# ------------
# Retrieving Results for Index 18: lompoc.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date             Hotel Name
# 1            48        88      PH  1650918158        SEGAYA PROPERTY
# 2            76        72      PF  1650917936        People ThankYou
# 10           26        58      PE  1650918162  Hospedaje Costa Bella
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...                    ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
# [122 rows x 10 columns] hotel is Holiday Inn Express Lompoc, an IHG Hotel.
# ------------
# Retrieving Results for Index 19: chabua.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Biru Rupam Hotel.
# ------------
# Retrieving Results for Index 23: vaini.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Keleti Beach Resort.
# ------------
# Retrieving Results for Index 38: jamestown.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Hampton Inn & Suites Jamestown.
# ------------
# Retrieving Results for Index 47: williamsport.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Hampton Inn Williamsport-Downtown.
# ------------
# Retrieving Results for Index 54: puerto ayora.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Finch Bay Galapagos Hotel.
# ------------
# Retrieving Results for Index 55: loa janan.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Ss.
# ------------
# Retrieving Results for Index 70: chiang klang.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Sangthong Resort.
# ------------
# Retrieving Results for Index 75: carnarvon.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Hospitality Carnarvon.
# ------------
# Retrieving Results for Index 77: banjar.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is The Hamsa Resort.
# ------------
# Retrieving Results for Index 87: hilo.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Hilo Hawaiian Hotel.
# ------------
# Retrieving Results for Index 88: georgetown.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Cititel Penang.
# ------------
# Retrieving Results for Index 92: mahebourg.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Shandrani Beachcomber Resort & Spa.
# ------------
# Retrieving Results for Index 95: kahului.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Maui Seaside Hotel.
# ------------
# Retrieving Results for Index 99: souillac.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Shanti Maurice Resort & Spa.
# ------------
# Retrieving Results for Index 101: japura.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# ...
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is HOTEL SAI SIDDHI.
# ------------
# Retrieving Results for Index 529: puerto baquerizo moreno.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Hotel los Algarrobos.
# ------------
# Retrieving Results for Index 535: fallon.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529                      Hotel los Algarrobos
# 535
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Best Western Fallon Inn & Suites.
# ------------
# Retrieving Results for Index 549: ambilobe.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529                      Hotel los Algarrobos
# 535          Best Western Fallon Inn & Suites
# 549
# 552
# 558
#
# [122 rows x 10 columns] hotel is Hôtel & Restaurant DIANA Ambilobe.
# ------------
# Retrieving Results for Index 552: rio negro.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529                      Hotel los Algarrobos
# 535          Best Western Fallon Inn & Suites
# 549         Hôtel & Restaurant DIANA Ambilobe
# 552
# 558
#
# [122 rows x 10 columns] hotel is Hotel Emacite Flex.
# ------------
# Retrieving Results for Index 558: qalyub.
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Closest                    City Name  Latitude  Longitude  Temperature  Wind Speed  \
# 1                     dingle   10.9995   122.6711        78.01        6.93
# 2                    rikitea  -23.1203  -134.9692        77.16       15.70
# 10                   sechura   -5.5569   -80.8222        79.88       12.55
# 18                    lompoc   34.6391  -120.4579        70.45       18.41
# 19                    chabua   27.4825    95.1736        70.02        4.41
# ..                       ...       ...        ...          ...         ...
# 529  puerto baquerizo moreno   -0.9000   -89.6000        79.79       11.50
# 535                   fallon   39.4735  -118.7774        71.11       11.50
# 549                 ambilobe  -13.2000    49.0500        73.24        4.32
# 552                rio negro  -26.1058   -49.7975        70.12        1.97
# 558                   qalyub   30.1792    31.2056        73.90       11.27
#
#      Cloudiness  Humidity Country        Date  \
# 1            48        88      PH  1650918158
# 2            76        72      PF  1650917936
# 10           26        58      PE  1650918162
# 18            0        59      US  1650918135
# 19           12        77      IN  1650918166
# ..          ...       ...     ...         ...
# 529          75        65      EC  1650918369
# 535          75        12      US  1650918371
# 549          98        83      MG  1650918377
# 552          71        69      BR  1650918378
# 558           3        56      EG  1650918381
#
#                                    Hotel Name
# 1                             SEGAYA PROPERTY
# 2                             People ThankYou
# 10                      Hospedaje Costa Bella
# 18   Holiday Inn Express Lompoc, an IHG Hotel
# 19                           Biru Rupam Hotel
# ..                                        ...
# 529                      Hotel los Algarrobos
# 535          Best Western Fallon Inn & Suites
# 549         Hôtel & Restaurant DIANA Ambilobe
# 552                        Hotel Emacite Flex
# 558
#
# [122 rows x 10 columns] hotel is كمال فهمى محمد فهمى.
# ------------
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City Name</dt><dd>{City Name}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>SEGAYA PROPERTY</dd>\n<dt>City Name</dt><dd>dingle</dd>\n<dt>Country</dt><dd>PH</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>People ThankYou</dd>\n<dt>City Name</dt><dd>rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospedaje Costa Bella</dd>\n<dt>City Name</dt><dd>sechura</dd>\n<dt>Country</dt><dd>PE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Lompoc, an IHG Hotel</dd>\n<dt>City Name</dt><dd>lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Biru Rupam Hotel</dd>\n<dt>City Name</dt><dd>chabua</dd>\n<dt>Country</dt><dd>IN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Keleti Beach Resort</dd>\n<dt>City Name</dt><dd>vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hampton Inn & Suites Jamestown</dd>\n<dt>City Name</dt><dd>jamestown</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hampton Inn Williamsport-Downtown</dd>\n<dt>City Name</dt><dd>williamsport</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Finch Bay Galapagos Hotel</dd>\n<dt>City Name</dt><dd>puerto ayora</dd>\n<dt>Country</dt><dd>EC</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ss</dd>\n<dt>City Name</dt><dd>loa janan</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sangthong Resort</dd>\n<dt>City Name</dt><dd>chiang klang</dd>\n<dt>Country</dt><dd>TH</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Carnarvon</dd>\n<dt>City Name</dt><dd>carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Hamsa Resort</dd>\n<dt>City Name</dt><dd>banjar</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilo Hawaiian Hotel</dd>\n<dt>City Name</dt><dd>hilo</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Cititel Penang</dd>\n<dt>City Name</dt><dd>georgetown</dd>\n<dt>Country</dt><dd>MY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shandrani Beachcomber Resort & Spa</dd>\n<dt>City Name</dt><dd>mahebourg</dd>\n<dt>Country</dt><dd>MU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maui Seaside Hotel</dd>\n<dt>City Name</dt><dd>kahului</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shanti Maurice Resort & Spa</dd>\n<dt>City Name</dt><dd>souillac</dd>\n<dt>Country</dt><dd>MU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rumah mbah Jamah</dd>\n<dt>City Name</dt><dd>japura</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Chambres d\'hôte "La Trinité"</dd>\n<dt>City Name</dt><dd>saint-philippe</dd>\n<dt>Country</dt><dd>RE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Disney’s Hilton Head Island Resort</dd>\n<dt>City Name</dt><dd>hilton head island</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>RIVÂT LODGE</dd>\n<dt>City Name</dt><dd>pouebo</dd>\n<dt>Country</dt><dd>NC</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aryaduta Hotel</dd>\n<dt>City Name</dt><dd>manado</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Xaguate</dd>\n<dt>City Name</dt><dd>sao filipe</dd>\n<dt>Country</dt><dd>CV</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Parque Residencial Canaima I</dd>\n<dt>City Name</dt><dd>guatire</dd>\n<dt>Country</dt><dd>VE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Villa Enata</dd>\n<dt>City Name</dt><dd>atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>CHACARA BAILLY</dd>\n<dt>City Name</dt><dd>castro</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Atlantis Hotel</dd>\n<dt>City Name</dt><dd>bathsheba</dd>\n<dt>Country</dt><dd>BB</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lambitu Hotel</dd>\n<dt>City Name</dt><dd>bima</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Isles Sunset Lodge</dd>\n<dt>City Name</dt><dd>butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>amapa</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Kecubung Hotel</dd>\n<dt>City Name</dt><dd>pangkalanbuun</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto Praia</dd>\n<dt>City Name</dt><dd>arraial do cabo</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sheraton Kauai Coconut Beach Resort</dd>\n<dt>City Name</dt><dd>kapaa</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mercure Padang</dd>\n<dt>City Name</dt><dd>padang</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Kost Pria</dd>\n<dt>City Name</dt><dd>meulaboh</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Chenango Valley State Park</dd>\n<dt>City Name</dt><dd>broome</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Posada del Inti Centro</dd>\n<dt>City Name</dt><dd>mercedes</dd>\n<dt>Country</dt><dd>AR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Le Manotel</dd>\n<dt>City Name</dt><dd>moerai</dd>\n<dt>Country</dt><dd>PF</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shams hotel</dd>\n<dt>City Name</dt><dd>nushki</dd>\n<dt>Country</dt><dd>PK</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shishime Hotel</dd>\n<dt>City Name</dt><dd>naze</dd>\n<dt>Country</dt><dd>JP</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Tia Villa</dd>\n<dt>City Name</dt><dd>bambous virieux</dd>\n<dt>Country</dt><dd>MU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vivi Palace</dd>\n<dt>City Name</dt><dd>matadi</dd>\n<dt>Country</dt><dd>CD</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>swayamprabha service apartments</dd>\n<dt>City Name</dt><dd>amalapuram</dd>\n<dt>Country</dt><dd>IN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>We Hotel Aeropuerto</dd>\n<dt>City Name</dt><dd>venustiano carranza</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Marriott's Ko Olina Beach Club</dd>\n<dt>City Name</dt><dd>makakilo city</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Castelo</dd>\n<dt>City Name</dt><dd>cidreira</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tanna Lodge</dd>\n<dt>City Name</dt><dd>isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Chik Chik Namibe</dd>\n<dt>City Name</dt><dd>namibe</dd>\n<dt>Country</dt><dd>AO</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>بيت ابو رباح</dd>\n<dt>City Name</dt><dd>hit</dd>\n<dt>Country</dt><dd>IQ</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pirineos</dd>\n<dt>City Name</dt><dd>san cristobal</dd>\n<dt>Country</dt><dd>VE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>ouegoa</dd>\n<dt>Country</dt><dd>NC</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>mangai</dd>\n<dt>Country</dt><dd>CD</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bay View Resort Myrtle Beach</dd>\n<dt>City Name</dt><dd>myrtle beach</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express & Suites Elk Grove Central - Hwy 99, an IHG Hotel</dd>\n<dt>City Name</dt><dd>laguna</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 2966 Hotel Atriaz</dd>\n<dt>City Name</dt><dd>trenggalek</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Playa Canela Hotel Boutique</dd>\n<dt>City Name</dt><dd>la libertad</dd>\n<dt>Country</dt><dd>EC</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel El Recreo</dd>\n<dt>City Name</dt><dd>general roca</dd>\n<dt>Country</dt><dd>AR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ramah Kost KITA</dd>\n<dt>City Name</dt><dd>pemangkat</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Suites Las Palmas</dd>\n<dt>City Name</dt><dd>ojinaga</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>sangueya</dd>\n<dt>Country</dt><dd>GN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>محطة التلفاز</dd>\n<dt>City Name</dt><dd>abu kamal</dd>\n<dt>Country</dt><dd>SY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pondok Wisata Elim</dd>\n<dt>City Name</dt><dd>waingapu</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>مروان /عدنان</dd>\n<dt>City Name</dt><dd>bayji</dd>\n<dt>Country</dt><dd>IQ</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada dos Navegantes</dd>\n<dt>City Name</dt><dd>caravelas</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Regency Hotel</dd>\n<dt>City Name</dt><dd>yanam</dd>\n<dt>Country</dt><dd>IN</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Ha'apai Beach Resort</dd>\n<dt>City Name</dt><dd>pangai</dd>\n<dt>Country</dt><dd>TO</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ibis Styles Karratha</dd>\n<dt>City Name</dt><dd>karratha</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Railway motel</dd>\n<dt>City Name</dt><dd>gazanjyk</dd>\n<dt>Country</dt><dd>TM</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Trinity Plains Tourist Park</dd>\n<dt>City Name</dt><dd>mareeba</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Salinas Park Resort Maçarico AP101</dd>\n<dt>City Name</dt><dd>salinopolis</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Ode Husein</dd>\n<dt>City Name</dt><dd>katobu</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Esplanade Hotel</dd>\n<dt>City Name</dt><dd>port hedland</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>LT Aparthotel</dd>\n<dt>City Name</dt><dd>praya</dd>\n<dt>Country</dt><dd>CV</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Ambulu Jember</dd>\n<dt>City Name</dt><dd>ambulu</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vitória Palace</dd>\n<dt>City Name</dt><dd>vila velha</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Delong Hotel</dd>\n<dt>City Name</dt><dd>shache</dd>\n<dt>Country</dt><dd>CN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pyramid Hotel</dd>\n<dt>City Name</dt><dd>sisophon</dd>\n<dt>Country</dt><dd>KH</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Peace Land Ishigakijima</dd>\n<dt>City Name</dt><dd>ishigaki</dd>\n<dt>Country</dt><dd>JP</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Dora, Bubaque</dd>\n<dt>City Name</dt><dd>bubaque</dd>\n<dt>Country</dt><dd>GW</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Semotswane Baraka Lodge</dd>\n<dt>City Name</dt><dd>tonota</dd>\n<dt>Country</dt><dd>BW</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>DoubleTree Suites by Hilton Hotel Columbus Downtown</dd>\n<dt>City Name</dt><dd>columbus</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Yos ega cv</dd>\n<dt>City Name</dt><dd>boyolangu</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>KOPKAR Hotel Bintang Sintuk</dd>\n<dt>City Name</dt><dd>bontang</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Taloa Heights</dd>\n<dt>City Name</dt><dd>alofi</dd>\n<dt>Country</dt><dd>NU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pousada 100 Passos</dd>\n<dt>City Name</dt><dd>tamandare</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>davao</dd>\n<dt>Country</dt><dd>PH</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Salama and Fast Food</dd>\n<dt>City Name</dt><dd>ambanja</dd>\n<dt>Country</dt><dd>MG</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grage Hotel Bengkulu</dd>\n<dt>City Name</dt><dd>bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Atoll Emerald Miyakojima</dd>\n<dt>City Name</dt><dd>hirara</dd>\n<dt>Country</dt><dd>JP</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sky Tower Hotel</dd>\n<dt>City Name</dt><dd>kashima</dd>\n<dt>Country</dt><dd>JP</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Monty Brooms Guest House</dd>\n<dt>City Name</dt><dd>mabaruma</dd>\n<dt>Country</dt><dd>GY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>masuguru</dd>\n<dt>Country</dt><dd>TZ</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>baherden</dd>\n<dt>Country</dt><dd>TM</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lindsey Hôtel</dd>\n<dt>City Name</dt><dd>saint-pierre</dd>\n<dt>Country</dt><dd>RE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Complejo Isabelino</dd>\n<dt>City Name</dt><dd>paso de los toros</dd>\n<dt>Country</dt><dd>UY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>East Arnhem Real Estate</dd>\n<dt>City Name</dt><dd>nhulunbuy</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Auberge’Inn</dd>\n<dt>City Name</dt><dd>jeremie</dd>\n<dt>Country</dt><dd>HT</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Western Plus Abbey Inn</dd>\n<dt>City Name</dt><dd>saint george</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Villa Kitzia Huacho</dd>\n<dt>City Name</dt><dd>hualmay</dd>\n<dt>Country</dt><dd>PE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Abaco Beach Resort</dd>\n<dt>City Name</dt><dd>marsh harbour</dd>\n<dt>Country</dt><dd>BS</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL PLACE YALABA</dd>\n<dt>City Name</dt><dd>kikwit</dd>\n<dt>Country</dt><dd>CD</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sunset Heal</dd>\n<dt>City Name</dt><dd>whithorn</dd>\n<dt>Country</dt><dd>JM</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Grand Continental Kuala Terengganu (4 Star)</dd>\n<dt>City Name</dt><dd>kuala terengganu</dd>\n<dt>Country</dt><dd>MY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>abu samrah</dd>\n<dt>Country</dt><dd>SY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Vahmoneh Lodge Vanimo</dd>\n<dt>City Name</dt><dd>vanimo</dd>\n<dt>Country</dt><dd>PG</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Khai Nga Hotel</dd>\n<dt>City Name</dt><dd>lang son</dd>\n<dt>Country</dt><dd>VN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>rawah</dd>\n<dt>Country</dt><dd>IQ</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>LT Aparthotel</dd>\n<dt>City Name</dt><dd>praia</dd>\n<dt>Country</dt><dd>CV</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sunrise Attitude Hotel</dd>\n<dt>City Name</dt><dd>quatre cocos</dd>\n<dt>Country</dt><dd>MU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City Name</dt><dd>marzuq</dd>\n<dt>Country</dt><dd>YE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Miramar</dd>\n<dt>City Name</dt><dd>huarmey</dd>\n<dt>Country</dt><dd>PE</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Birjand Tourist Hotel</dd>\n<dt>City Name</dt><dd>birjand</dd>\n<dt>Country</dt><dd>IR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rikito Lodge</dd>\n<dt>City Name</dt><dd>tambura</dd>\n<dt>Country</dt><dd>SS</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rest House</dd>\n<dt>City Name</dt><dd>kuliyapitiya</dd>\n<dt>Country</dt><dd>LK</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nancy Montanes Bernardo</dd>\n<dt>City Name</dt><dd>dicabisagan</dd>\n<dt>Country</dt><dd>PH</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL SAI SIDDHI</dd>\n<dt>City Name</dt><dd>ramanuj ganj</dd>\n<dt>Country</dt><dd>IN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel los Algarrobos</dd>\n<dt>City Name</dt><dd>puerto baquerizo moreno</dd>\n<dt>Country</dt><dd>EC</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Best Western Fallon Inn & Suites</dd>\n<dt>City Name</dt><dd>fallon</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hôtel & Restaurant DIANA Ambilobe</dd>\n<dt>City Name</dt><dd>ambilobe</dd>\n<dt>Country</dt><dd>MG</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Emacite Flex</dd>\n<dt>City Name</dt><dd>rio negro</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>كمال فهمى محمد فهمى</dd>\n<dt>City Name</dt><dd>qalyub</dd>\n<dt>Country</dt><dd>EG</dd>\n</dl>\n']

# %%
# Add marker layer ontop of heat map


# Display figure

marker_layer = gmaps.marker_layer(
    locations, 
    info_box_content = hotel_info
)

fig = gmaps.figure()
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
